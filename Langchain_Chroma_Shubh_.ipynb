# %%
pip install -U langchain-core langchain-community langchain-openai langchain-chroma chromadb tiktoken

# %%
import os

os.environ["OPENAI_API_KEY"] = "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"
os.environ["OPENAI_API_BASE"] = "https://openrouter.ai/api/v1"

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document

# %%
from langchain_core.documents import Document

# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
vector_store = Chroma(
    embedding_function=OpenAIEmbeddings(),
    persist_directory='my_chroma_db',
    collection_name='sample'
)

# %%
vector_store.add_documents(docs)
# Out:
# ['23814dad-bfab-4a71-8318-3312088eedf7',
#  '028b6d0a-f3f9-47f2-a2d1-d5c986b8cc58',
#  'e58e9892-9506-491b-ae56-ee58252a448d',
#  '80bc8eb9-e467-446e-b4e7-17045016a437',
#  '8913bbd5-e246-48b2-8772-4a27c97c1e88']

# %%
vector_store.get(include=["documents", "metadatas","embeddings"])
# Out:
# {'ids': ['23814dad-bfab-4a71-8318-3312088eedf7',
#   '028b6d0a-f3f9-47f2-a2d1-d5c986b8cc58',
#   'e58e9892-9506-491b-ae56-ee58252a448d',
#   '80bc8eb9-e467-446e-b4e7-17045016a437',
#   '8913bbd5-e246-48b2-8772-4a27c97c1e88'],
#  'embeddings': array([[-2.07734108e-03, -2.16356432e-03,  2.67739072e-02, ...,
#          -1.70658119e-02, -3.68524459e-03,  1.35402400e-02],
#         [-2.70681921e-03, -5.47363961e-05,  2.82030534e-02, ...,
#          -1.50933377e-02,  5.93815418e-03, -1.16601437e-02],
#         [ 7.83727213e-04, -4.76402277e-03,  1.23708826e-02, ...,
#          -1.72387529e-02,  7.74397107e-04,  2.93532619e-03],
#         [-2.71391869e-02,  8.87096301e-03,  2.69362777e-02, ...,
#          -2.58583203e-02,  9.02314577e-03, -1.99992992e-02],
#         [-1.81433018e-02,  1.27527108e-02,  3.47932205e-02, ...,
#          -3.03654689e-02, -5.85236121e-03,  5.21374308e-03]]),
# ...

# %%
vector_store.similarity_search(
    query="Who among these are a bowler?",
    k=2
)
# Out:
# [Document(id='80bc8eb9-e467-446e-b4e7-17045016a437', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(id='8913bbd5-e246-48b2-8772-4a27c97c1e88', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.')]

# %%
vector_store.similarity_search_with_score(
    query="Who among these are a bowler?",
    k=2
)
# Out:
# [(Document(id='80bc8eb9-e467-446e-b4e7-17045016a437', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.35432544350624084),
#  (Document(id='8913bbd5-e246-48b2-8772-4a27c97c1e88', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.4086669683456421)]

# %%
vector_store.similarity_search_with_score(
    query="",
    filter={"team": "Chennai Super Kings"}
)
# Out:
# [(Document(id='e58e9892-9506-491b-ae56-ee58252a448d', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   0.6485780477523804),
#  (Document(id='8913bbd5-e246-48b2-8772-4a27c97c1e88', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.6563354730606079)]

# %%
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='23814dad-bfab-4a71-8318-3312088eedf7', document=updated_doc1)

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['23814dad-bfab-4a71-8318-3312088eedf7',
#   '028b6d0a-f3f9-47f2-a2d1-d5c986b8cc58',
#   'e58e9892-9506-491b-ae56-ee58252a448d',
#   '80bc8eb9-e467-446e-b4e7-17045016a437',
#   '8913bbd5-e246-48b2-8772-4a27c97c1e88'],
#  'embeddings': array([[-1.02899913e-02, -1.90612599e-02,  8.13256833e-04, ...,
#          -1.78128183e-02,  2.02871789e-03,  9.32470150e-03],
#         [-2.70681921e-03, -5.47363961e-05,  2.82030534e-02, ...,
#          -1.50933377e-02,  5.93815418e-03, -1.16601437e-02],
#         [ 7.83727213e-04, -4.76402277e-03,  1.23708826e-02, ...,
#          -1.72387529e-02,  7.74397107e-04,  2.93532619e-03],
#         [-2.71391869e-02,  8.87096301e-03,  2.69362777e-02, ...,
#          -2.58583203e-02,  9.02314577e-03, -1.99992992e-02],
#         [-1.81433018e-02,  1.27527108e-02,  3.47932205e-02, ...,
#          -3.03654689e-02, -5.85236121e-03,  5.21374308e-03]]),
# ...

# %%
vector_store.delete(ids=['23814dad-bfab-4a71-8318-3312088eedf7'])

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['028b6d0a-f3f9-47f2-a2d1-d5c986b8cc58',
#   'e58e9892-9506-491b-ae56-ee58252a448d',
#   '80bc8eb9-e467-446e-b4e7-17045016a437',
#   '8913bbd5-e246-48b2-8772-4a27c97c1e88'],
#  'embeddings': array([[-2.70681921e-03, -5.47363961e-05,  2.82030534e-02, ...,
#          -1.50933377e-02,  5.93815418e-03, -1.16601437e-02],
#         [ 7.83727213e-04, -4.76402277e-03,  1.23708826e-02, ...,
#          -1.72387529e-02,  7.74397107e-04,  2.93532619e-03],
#         [-2.71391869e-02,  8.87096301e-03,  2.69362777e-02, ...,
#          -2.58583203e-02,  9.02314577e-03, -1.99992992e-02],
#         [-1.81433018e-02,  1.27527108e-02,  3.47932205e-02, ...,
#          -3.03654689e-02, -5.85236121e-03,  5.21374308e-03]]),
#  'documents': ["Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
# ...
